# %% [markdown]
# Models Integration with OpenAI, Google Gemini, Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-5")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.17', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-5', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True, 'reasoning_effort_levels': ['none', 'low', 'medium', 'high', 'xhigh']}, client=<openai.resources.chat.completions.completions.Completions object at 0x11a2a2350>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11a2a2ad0>, root_client=<openai.OpenAI object at 0x11a2a2490>, root_async_client=<openai.AsyncOpenAI object at 0x11a2a2850>, model_name='gpt-5', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
#invoke the model with a prompt
prompt = "Write a poem about the beauty of nature."
response = model.invoke(prompt)
print(response)

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model(
    model="gemini-3.6-flash",
    model_provider="google_genai")
response = model.invoke("why do parrots talk?")
print(response)
# Out:
# content=[{'type': 'text', 'text': 'Parrots "talk" primarily because they are **highly social creatures with a deep evolutionary need to fit in with their flock.** \n\nWhen kept as pets, parrots view humans as their new flock. Because they lack the natural ability to instinctively know a set of species-specific calls, they must *learn* how to communicate from those around them. \n\nHere is a detailed breakdown of why and how parrots talk:\n\n---\n\n### 1. The "Flock" Instinct (Social Bonding)\nIn the wild, wild parrots live in dense, noisy flocks. Different wild flocks even have different "dialects." A parrot learns the specific calls of its flock so it can:\n* Identify its family members.\n* Warn others of predators.\n* Stay connected in dense foliage.\n\nIn a home, **you are the parrot’s flock.** To fit in and bond with you, the parrot mimics the sounds you make—which happen to be human words, laughter, or the sound of the microwave.\n\n---\n\n### 2. Seeking Attention and Rewards\nParrots are extremely intelligent and observant. They quickly learn cause and effect:\n* *If I make a barking sound or say "Hello," the human looks at me, talks to me, or gives me a treat.*\n\nBecause they thrive on attention, they will repeat words and phrases that get a big reaction from their owners.\n\n---\n\n### 3. Unique Brain Structure\nParrots are among the very few animals in the world capable of **vocal learning** (the ability to hear a sound and reproduce it). \n\nScientists discovered that parrot brains have a unique structure: inside the brain’s "vocal control centers," parrots have an extra outer ring or "shell." This specialized brain area allows them to process complex auditory information and gives them exceptional control over the sounds they produce.\n\n---\n\n### 4. How Do They Do It Without Lips or Vocal Cords?\nHumans make words using vocal cords, lips, and teeth. Parrots don\'t have any of these. Instead, they use:\n* **The Syrinx:** A vocal organ located at the base of their trachea (windpipe). By controlling the muscles and depth of the syrinx, they can imitate vowels and consonants.\n* **Their Tongue and Beak:** Parrots use their thick, muscular tongues and the shape of their beaks to alter the air currents, creating sounds that closely mimic human speech.\n\n---\n\n### Do Parrots Actually Understand What They Are Saying?\nFor the most part, parrots use **contextual association** rather than actual language understanding. \n* They might say *"Good morning!"* when you uncover their cage because they have learned that phrase happens at that specific time.\n* They might say *"Want a treat?"* when you walk into the kitchen because they associate that sound with getting food.\n\nHowever, some exceptionally trained parrots (like the famous African Grey parrot named **Alex**) have demonstrated a deeper understanding—learning to correctly use words to identify colors, shapes, quantities, and even express feelings like "I want to go back to my cage."\n\n---\n\n### Summary\nParrots talk because **their brains are built for sound imitation, and their social instinct drives them to copy the "calls" of their human family to feel included.**', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a03da5-2451-7bd3-b11e-50ee63e7dfd8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 1622, 'total_tokens': 1628, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 939}}

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.6-flash")
response = model.invoke("why do parrots talk?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Parrots talk—or more accurately, **mimic human speech**—due to a combination of their evolutionary biology, high intelligence, and deeply social nature. \n\nHere is a breakdown of why and how parrots are able to talk:\n\n---\n\n### 1. Social Structure and the "Flock" Instinct\nIn the wild, parrots are intensely social animals that live in complex flocks. Communication is vital for their survival. \n* **Flock Dialects:** Wild parrots use vocal cues to identify members of their flock, coordinate movement, and warn off predators. Different flocks even develop distinct "dialects."\n* **Fitting In:** When a parrot is kept as a pet, it doesn\'t have a bird flock. It views its human family as its new flock. To fit in and communicate with its human "flock mates," the parrot listens to the sounds humans make and mimics them.\n\n### 2. High Intelligence and Brain Structure\nParrots are among the most intelligent birds on Earth, with brain capabilities comparable to primates. \n* **Vocal Learning Centers:** Scientists have discovered that parrot brains have specialized structures called "song nuclei" that control vocal learning. \n* **The "Shell" System:** Unlike songbirds (like canaries) which only have a central "core" in these brain regions, parrots also have an outer "shell" layer around these nuclei. This unique brain anatomy gives them superior flexibility in copying complex sounds, including human words, ringing phones, or barking dogs.\n\n### 3. Biology: The Syrinx (Not Vocal Cords)\nHumans produce speech using vocal cords, a larynx, lips, and teeth. Parrots don\'t have vocal cords; instead, they use a unique organ called the **syrinx**, located at the base of their trachea (windpipe).\n* By manipulating the muscles surrounding the syrinx and controlling airflow from their lungs, parrots can produce a astonishing range of sounds.\n* They also use their **tongue and beak** to shape the air and mimic human vowels and consonants with incredible accuracy.\n\n### 4. Positive Reinforcement and Attention\nParrots learn quickly that speaking human words gets a strong reaction. \n* If a parrot says "Hello!" or "Pretty bird," humans usually laugh, talk back, smile, or give them a treat. \n* Because parrots crave interaction, this **positive reinforcement** encourages them to repeat those specific words to get attention, food, or play time.\n\n---\n\n### Do parrots actually understand what they are saying?\n\nFor the most part, parrots use **functional mimicry** or **associative learning**. \n* They might not know the grammatical definition of "Goodnight," but they understand that saying it coincides with the lights turning off or a cover going over their cage.\n* They might say "Want a nut?" because they associate that specific sound with receiving a treat.\n\nHowever, some exceptionally smart parrots—most famously **Alex**, an African Grey researched by Dr. Irene Pepperberg—have shown the ability to use human words to categorize objects, identify colors, count up to six, and express actual desires (e.g., asking for a specific food). \n\n### Summary\nParrots talk because **their brains and anatomy allow them to**, and **their desire for social connection drives them to do it**. In a human home, mimicking human speech is the ultimate way for a parrot to bond with its family.', 'extras': {'signature': '...'}}]

# %% [markdown]
# #### GROQ MODEL INTEGRATION

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
    model="groq:qwen/qwen3.6-27b"
)

response = model.invoke("Write a poem about the beauty of nature.")
print(response.content)
# Out:
# <think>
# Thinking Process:
#
# 1.  **Deconstruct the Request:**
#     *   Topic: Beauty of nature.
#     *   Format: Poem.
#
# 2.  **Brainstorming Imagery and Themes:**
#     *   *Sights:* Sunlight, forests, oceans, mountains, flowers, stars, seasons changing.
#     *   *Sounds:* Birds singing, wind rustling, waves crashing, silence.
#     *   *Feelings:* Peace, awe, renewal, connection, timelessness.
#     *   *Metaphors:* Nature as a painter, a symphony, a healer, an ancient wisdom.
#
# 3.  **Structuring the Poem:**
#     *   I need a flow. Maybe move through different elements or times of day.
#     *   *Option A1: Chronological.* Dawn -> Day -> Dusk -> Night.
#     *   *Option B2: Elemental.* Earth -> Water -> Air -> Fire/Sky.
#     *   *Option C3: Macro to Micro.* Mountains -> Forest -> Flower -> Dewdrop.
#     *   *Decision:* A blend of Option A1 and B2 often works well for a general "beauty of nature" poem. It allows for a rhythmic progression. Let's aim for a structure that feels expansive yet intimate. Four stanzas might be good, or five. Let's try five for a complete arc: Morning/Light, Forest/Growth, Water/Flow, Night/Stars, Conclusion/Soul.
#
# 4.  **Drafting - Stanza by Stanza:**
#     *   *Stanza 1: Morning/Light.*
#         *   Keywords: Dawn, gold, whisper, waking.
#         *   Lines: The sun spills gold upon the hill. The mist retreats. The world wakes up.
#         *   *Refinement:* "The dawn unspools a ribbon of gold," "Across the sleeping valleys cold." "A whisper wakes the fern and pine," "In rhythms of an ancient design."
#         *   *Rhyme Scheme:* AABB or ABAB? ABAB feels more lyrical for nature. Let's try ABAB.
#         *   *Drafting1:*
#         The dawn unspools a ribbon of gold,
#         Across the hills where shadows sleep,
#         A story in the meadows told,
#         While rivers wake from winter's deep.
#         *Critique:* "Winter's deep" is okay, but maybe "slumber deep" is better? "Rivers wake from slumber deep." Good.
#
#     *   *Stanza 2: Forest/Life.*
#         *   Keywords: Trees, leaves, birds, green, breath.
#         *   Lines: The trees stand tall. Leaves dance. Birds sing.
#         *   *Refinement:* "The ancient woods breathe deep and slow," "With emerald robes of moss and vine." "The wind begins its soft caress," "To weave the leaves into a chime."
#         *   *Drafting2:*
#         The ancient woods breathe deep and slow,
#         Clad in emerald robes of green,
#         Where mossy stones and ferns grow,
#         And hidden streams are barely seen.
#         *Critique:* "Barely seen" is a bit cliché. Let's focus on the sound or light. "Where dappled light on bark is seen"? No. "Where sunlight filters, bright and keen"? Better.
#         *Revised Stanza 2:*
#         The ancient woods breathe deep and slow,
#         Clad in emerald robes of green,
#         Where sunlight filters, soft and low,
#         Through canopies of towering green.
#         *Wait, rhyme issue.* Green/Green repetition.
#         *Fix:*
#         The ancient woods breathe deep and slow,
#         Clad in emerald robes of hue,
#         Where secrets of the earth may grow,
#         And roots drink deep the morning dew.
#         *Better.*
#
#     *   *Stanza 3: Water/Ocean.*
#         *   Keywords: Blue, crash, salt, mirror, vast.
#         *   Lines: The ocean roars. The lake reflects. Water shapes the stone.
#         *   *Refinement:* "The ocean sings its salt-laced song," "Against the cliffs of jagged stone." "The water pulls the day along," "And leaves a foam like lace alone."
#         *   *Drafting3:*
#         The ocean hums a salt-laced song,
#         Against the cliffs of jagged gray,
#         Where white-capped waves forever throng,
#         To kiss the shore and roll away.
#         *Critique:* "Throng" is a bit awkward. "Where white-capped waves forever long"? No. "Where restless waves forever throng"? Still awkward.
#         *Fix:*
#         The ocean hums a salt-laced song,
#         Against the cliffs of weathered stone,
#         Where waves in crests of froth belong,
#         And dance a rhythm all their own.
#         *Good.*
#
#     *   *Stanza 4: Night/Sky.*
#         *   Keywords: Stars, moon, silence, velvet.
#         *   Lines: The sun goes down. Stars come out. The moon watches.
#         *   *Refinement:* "Then twilight paints the sky in purple," "As stars ignite their diamond fires." "The moon ascends, a silver orb," "And lulls the world to quiet wires?" No.
#         *   *Drafting4:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond sparks,
#         The moon begins her silent walk,
#         To guide the dreams within the dark.
#         *Critique:* "Silent walk" is okay. "Diamond sparks" is nice. "Velvet cloak" is classic.
#         *Refinement:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their silver fire,
#         The moon awakes to watch and oke? No.
#         *Fix:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silent walk,
#         To guard the dreams of deep desire? No, that's too romantic/human.
#         *Fix:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silent track,
#         To calm the world with cold desire? No.
#         *Fix:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silver track,
#         To calm the heart with cool desire? No.
#         *Back to basics:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon rises, a pearl white stone,
#         Upon the dark, a calm siren? No.
#         *Let's try:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silent track,
#         To calm the soul with cool desire? Still stuck on desire.
#         *Better rhyme:*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silent track,
#         To soothe the world with cool desire? No.
#         *Let's change the rhyme words.*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silent track,
#         A beacon in the deep desire? No.
#         *Okay, let's swap "fire" and "track".*
#         As twilight weaves a velvet cloak,
#         And stars ignite their diamond fire,
#         The moon ascends her silver track,
#         To calm the heart's wild desire? No.
#         *Let's use "night" and "light".*
#         As twilight fades to indigo,
#         And stars begin to softly gleam,
#         The wind begins its hush and blow,
#         To rock the world within a dream.
#         *Critique:* "Hush and blow" is weak. "Indigo" and "gleam" don't rhyme.
#         *Back to ABAB.*
#         As twilight fades to indigo,
#         The stars awake to pierce the deep,
#         Where silent constellations glow,
#         And lull the valleys into sleep.
#         *Good. Simple, effective.*
#
#     *   *Stanza 5: Conclusion/Synthesis.*
#         *   Keywords: Soul, mirror, beauty, wild, free.
#         *   Lines: Nature is beautiful. It heals us. We are part of it.
#         *   *Refinement:* "Oh nature, wild and free and vast," "You paint the world with grace and power." "In every leaf and shadow cast," "You show us what is pure and flower?" No.
#         *   *Drafting5:*
#         Oh, nature, wild and vast and free,
#         You paint the world with grace and might,
#         A symphony for all to see,
#         That guides the spirit through the night.
#         *Critique:* "Symphony for all to see" mixes senses.
#         *Fix:*
#         Oh, nature, wild and vast and free,
#         You weave a tapestry of light,
#         For every heart that seeks to see,
#         And find its peace within your sight.
#         *
