# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# create an AI message manually (eg for conversation history)
ai_msg = AIMessage(content="Hello! How can I assist you today?")

messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="Can you help me?"),
    ai_msg,
    HumanMessage(content="Great! What is 2 + 2?")
]

response = model.invoke(messages)
print(response.content)

# %%
from langchain.messages import AIMessage, HumanMessage
from langchain.messages import ToolMessage

ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "New York"},
        "id": "call_123"
    }]
)

#Execute the tool and create the result message
weather_result = "Its sunny in New York, 75 degrees Fahrenheit."
tool_result_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

#continue conversation
messages = [
    HumanMessage("What is the weather in New York?"),
    ai_message,
    tool_result_message,
]

response = model.invoke(messages)
print(response.content)
